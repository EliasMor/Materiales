# %%
# ============================================================================
# AUTOMATIZACIÓN CON HERRAMIENTAS NO-CODE
# Introducción práctica a Zapier y conectores
# ============================================================================

def crear_banner(titulo, emoji="🚀", ancho=80):
    """Crear banners visuales atractivos"""
    linea = "=" * ancho
    print(f"\n{linea}")
    print(f"{emoji} {titulo.center(ancho-4)} {emoji}")
    print(f"{linea}\n")

def mostrar_paso(numero, titulo, descripcion, tips=None):
    """Mostrar pasos de forma clara"""
    print(f" **PASO {numero}: {titulo}**")
    print(f"   {descripcion}")
    if tips:
        print("    Tips:")
        for tip in tips:
            print(f"      • {tip}")
    print()

# ============================================================================
# PARTE 1: ¿QUÉ ES ZAPIER Y POR QUÉ USARLO?
# ============================================================================

crear_banner("ZAPIER: AUTOMATIZACIÓN SIN CÓDIGO", "⚡")

print(" **¿Qué es Zapier?**")
print("   Zapier es una plataforma que conecta más de 5,000 aplicaciones")
print("   para automatizar tareas repetitivas SIN necesidad de programar.")
print()

print(" **Conceptos básicos que DEBES conocer:**")
conceptos_zapier = {
    "ZAP": "Una automatización completa (ej: Gmail → Google Sheets)",
    "TRIGGER": "El evento que inicia la automatización (ej: nuevo email)",
    "ACTION": "Lo que sucede después del trigger (ej: crear fila en Sheets)",
    "FILTER": "Condición para que se ejecute (ej: solo emails importantes)",
    "FORMATTER": "Herramienta para modificar datos (ej: cambiar formato de fecha)",
    "DELAY": "Pausa entre acciones (ej: esperar 5 minutos)",
    "PATH": "Diferentes rutas según condiciones (ej: si/entonces)"
}

for concepto, definicion in conceptos_zapier.items():
    print(f"    **{concepto}**: {definicion}")

print()
print(" **Planes de Zapier (2024):**")
planes_zapier = [
    ("FREE", "100 tareas/mes", "Zaps de 2 pasos", "Ideal para probar"),
    ("STARTER", "$19.99/mes", "750 tareas/mes", "Zaps multi-paso, filtros"),
    ("PROFESSIONAL", "$49/mes", "2,000 tareas/mes", "Paths, formatters, webhooks"),
    ("TEAM", "$69/mes", "50,000 tareas/mes", "Colaboración, carpetas compartidas"),
    ("COMPANY", "$103/mes", "100,000 tareas/mes", "SSO, admin avanzado")
]

for plan, precio, tareas, caracteristicas in planes_zapier:
    print(f"    **{plan}**: {precio} - {tareas} - {caracteristicas}")

# ============================================================================
# PARTE 2: APLICACIONES MÁS POPULARES EN ZAPIER
# ============================================================================

crear_banner("APLICACIONES MÁS POPULARES", "📱")

print(" **TOP 20 APLICACIONES MÁS CONECTADAS:**")
print()

apps_populares = {
    " EMAIL & COMUNICACIÓN": [
        ("Gmail", "Gestión de emails", "Triggers: nuevo email, email etiquetado"),
        ("Outlook", "Email empresarial", "Actions: enviar email, crear evento calendario"),
        ("Slack", "Comunicación equipos", "Enviar mensajes, crear canales"),
        ("Microsoft Teams", "Colaboración", "Notificaciones, reuniones")
    ],
    " HOJAS DE CÁLCULO": [
        ("Google Sheets", "Hojas de cálculo", "Crear/actualizar filas, obtener datos"),
        ("Excel Online", "Hojas Microsoft", "Sincronización con Office 365"),
        ("Airtable", "Base datos visual", "Crear registros, actualizar campos")
    ],
    " ALMACENAMIENTO": [
        ("Google Drive", "Almacenamiento", "Subir archivos, crear carpetas"),
        ("Dropbox", "Sincronización", "Backup automático, compartir"),
        ("OneDrive", "Microsoft cloud", "Integración Office")
    ],
    " CRM & VENTAS": [
        ("HubSpot", "CRM completo", "Crear contactos, deals, tareas"),
        ("Salesforce", "CRM empresarial", "Leads, oportunidades, reportes"),
        ("Pipedrive", "CRM simple", "Pipeline de ventas")
    ],
    " CALENDARIOS": [
        ("Google Calendar", "Calendario Google", "Crear eventos, recordatorios"),
        ("Calendly", "Programación citas", "Automatizar bookings"),
        ("Outlook Calendar", "Calendario Microsoft", "Reuniones, invitaciones")
    ],
    " E-COMMERCE": [
        ("Shopify", "Tienda online", "Nuevos pedidos, productos, clientes"),
        ("WooCommerce", "WordPress shop", "Gestión pedidos"),
        ("Stripe", "Pagos online", "Nuevos pagos, suscripciones")
    ],
    " REDES SOCIALES": [
        ("Facebook Pages", "Páginas empresa", "Nuevos posts, comentarios"),
        ("Twitter", "Microblogging", "Nuevos tweets, menciones"),
        ("LinkedIn", "Red profesional", "Conexiones, posts empresa")
    ],
    " GESTIÓN PROYECTOS": [
        ("Trello", "Tableros Kanban", "Crear tarjetas, mover listas"),
        ("Asana", "Gestión tareas", "Proyectos, asignaciones"),
        ("Monday.com", "Work OS", "Automatización workflows")
    ]
}

for categoria, apps in apps_populares.items():
    print(f"{categoria}")
    for app, descripcion, funciones in apps:
        print(f"    **{app}**: {descripcion}")
        print(f"       {funciones}")
    print()

# ============================================================================
# PARTE 3: TUTORIAL PASO A PASO - TU PRIMER ZAP
# ============================================================================

crear_banner("TUTORIAL: CREAR TU PRIMER ZAP", "🎯")

print(" **OBJETIVO**: Crear un Zap que cuando recibas un email importante")
print("   en Gmail, automáticamente:")
print("   1. Cree una fila en Google Sheets")
print("   2. Envíe una notificación a Slack")
print("   3. Cree una tarea en Trello")
print()

print("  **TIEMPO ESTIMADO**: 15-20 minutos")
print(" **REQUISITOS**: Cuentas en Gmail, Google Sheets, Slack, Trello")
print()

# PASO 1: CONFIGURAR EL TRIGGER
mostrar_paso(
    1,
    "CONFIGURAR EL TRIGGER (Gmail)",
    "Configuramos Gmail para que detecte emails importantes",
    [
        "Ve a zapier.com y haz clic en 'Make a Zap'",
        "Busca 'Gmail' en el trigger",
        "Selecciona 'New Email' como evento",
        "Conecta tu cuenta de Gmail (autorización OAuth)",
        "En 'Label', selecciona 'Important' o 'Starred'",
        "Prueba el trigger con un email real"
    ]
)

# PASO 2: AGREGAR FILTRO
mostrar_paso(
    2,
    "AGREGAR FILTRO (Opcional pero recomendado)",
    "Filtramos para que solo se ejecute con emails específicos",
    [
        "Haz clic en '+' para agregar paso",
        "Selecciona 'Filter by Zapier'",
        "Condición: 'Subject' contains 'URGENTE'",
        "O también: 'From' contains 'cliente'",
        "Esto evita que se ejecute con todos los emails"
    ]
)

# PASO 3: PRIMERA ACCIÓN - GOOGLE SHEETS
mostrar_paso(
    3,
    "PRIMERA ACCIÓN: Google Sheets",
    "Creamos una fila en Google Sheets con los datos del email",
    [
        "Haz clic en '+' para agregar acción",
        "Busca 'Google Sheets'",
        "Selecciona 'Create Spreadsheet Row'",
        "Conecta tu cuenta de Google",
        "Selecciona tu hoja de cálculo existente",
        "Mapea los campos: Fecha, Remitente, Asunto, Cuerpo"
    ]
)

# PASO 4: SEGUNDA ACCIÓN - SLACK
mostrar_paso(
    4,
    "SEGUNDA ACCIÓN: Slack",
    "Enviamos notificación al canal de Slack del equipo",
    [
        "Haz clic en '+' para agregar otra acción",
        "Busca 'Slack'",
        "Selecciona 'Send Channel Message'",
        "Conecta tu workspace de Slack",
        "Selecciona el canal (ej: #urgente)",
        "Mensaje: '🚨 Email urgente de {{remitente}}: {{asunto}}'"
    ]
)

# PASO 5: TERCERA ACCIÓN - TRELLO
mostrar_paso(
    5,
    "TERCERA ACCIÓN: Trello",
    "Creamos una tarjeta en Trello para hacer seguimiento",
    [
        "Haz clic en '+' para agregar tercera acción",
        "Busca 'Trello'",
        "Selecciona 'Create Card'",
        "Conecta tu cuenta de Trello",
        "Selecciona tablero y lista",
        "Título: 'Responder: {{asunto}}'",
        "Descripción: 'Email de {{remitente}} recibido el {{fecha}}'"
    ]
)

# PASO 6: PROBAR Y ACTIVAR
mostrar_paso(
    6,
    "PROBAR Y ACTIVAR",
    "Probamos todo el flujo y lo activamos",
    [
        "Haz clic en 'Test & Review'",
        "Revisa que todos los pasos funcionen",
        "Si hay errores, revisa las conexiones",
        "Dale nombre a tu Zap: 'Emails Urgentes → Sheets + Slack + Trello'",
        "Haz clic en 'Publish' para activarlo"
    ]
)

print(" **¡FELICIDADES!** Has creado tu primer Zap multi-paso")
print("   Ahora cada email importante se procesará automáticamente")
print()

# ============================================================================
# PARTE 4: EJEMPLOS PRÁCTICOS POR INDUSTRIA
# ============================================================================

crear_banner("EJEMPLOS PRÁCTICOS POR INDUSTRIA", "🏭")

ejemplos_industria = {
    " RETAIL / E-COMMERCE": [
        {
            "nombre": "Nuevo Pedido → Notificaciones",
            "trigger": "Shopify: New Order",
            "acciones": [
                "Gmail: Enviar confirmación personalizada al cliente",
                "Slack: Notificar al equipo de fulfillment",
                "Google Sheets: Actualizar inventario",
                "Trello: Crear tarjeta de seguimiento"
            ],
            "beneficio": "Respuesta inmediata, mejor experiencia cliente",
            "tiempo_setup": "20 minutos"
        },
        {
            "nombre": "Producto Sin Stock → Reabastecimiento",
            "trigger": "Shopify: Product Updated (stock = 0)",
            "acciones": [
                "Gmail: Notificar a proveedor automáticamente",
                "Airtable: Crear registro de reabastecimiento",
                "Slack: Alertar al equipo de compras"
            ],
            "beneficio": "Nunca quedarse sin stock",
            "tiempo_setup": "15 minutos"
        }
    ],
    " SERVICIOS PROFESIONALES": [
        {
            "nombre": "Nuevo Lead → Seguimiento Inmediato",
            "trigger": "Formulario Web: New Submission",
            "acciones": [
                "HubSpot: Crear contacto y deal",
                "Gmail: Enviar email de bienvenida",
                "Google Calendar: Agendar llamada de seguimiento",
                "Slack: Notificar al vendedor asignado"
            ],
            "beneficio": "0% leads perdidos, seguimiento inmediato",
            "tiempo_setup": "25 minutos"
        },
        {
            "nombre": "Proyecto Completado → Facturación",
            "trigger": "Trello: Card Moved to 'Completed'",
            "acciones": [
                "QuickBooks: Crear factura automática",
                "Gmail: Enviar factura al cliente",
                "Google Sheets: Actualizar reporte financiero"
            ],
            "beneficio": "Facturación inmediata, mejor cash flow",
            "tiempo_setup": "30 minutos"
        }
    ],
    " SALUD Y BIENESTAR": [
        {
            "nombre": "Nueva Cita → Recordatorios",
            "trigger": "Calendly: New Event Scheduled",
            "acciones": [
                "Gmail: Enviar confirmación con instrucciones",
                "SMS (via Twilio): Recordatorio 24h antes",
                "Google Sheets: Actualizar agenda del doctor",
                "Slack: Notificar a recepción"
            ],
            "beneficio": "Menos no-shows, mejor organización",
            "tiempo_setup": "20 minutos"
        }
    ],
    " EDUCACIÓN": [
        {
            "nombre": "Nuevo Estudiante → Onboarding",
            "trigger": "Typeform: New Response",
            "acciones": [
                "Gmail: Enviar kit de bienvenida",
                "Google Classroom: Agregar a curso",
                "Slack: Crear canal privado",
                "Airtable: Crear perfil de estudiante"
            ],
            "beneficio": "Onboarding automático y completo",
            "tiempo_setup": "25 minutos"
        }
    ],
    " INMOBILIARIA": [
        {
            "nombre": "Nueva Consulta → Seguimiento",
            "trigger": "Facebook Lead Ads: New Lead",
            "acciones": [
                "CRM: Crear contacto",
                "WhatsApp Business: Enviar mensaje automático",
                "Google Sheets: Agregar a lista de prospectos",
                "Google Calendar: Agendar visita"
            ],
            "beneficio": "Respuesta en menos de 5 minutos",
            "tiempo_setup": "20 minutos"
        }
    ]
}

for industria, casos in ejemplos_industria.items():
    print(f"{industria}")
    print("-" * 50)

    for caso in casos:
        print(f"\n    **{caso['nombre']}**")
        print(f"    Trigger: {caso['trigger']}")
        print(f"    Acciones:")
        for accion in caso['acciones']:
            print(f"      • {accion}")
        print(f"    Beneficio: {caso['beneficio']}")
        print(f"    Tiempo setup: {caso['tiempo_setup']}")
    print()

# ============================================================================
# PARTE 5: CONECTORES ESPECÍFICOS - GUÍAS DETALLADAS
# ============================================================================

crear_banner("GUÍAS DETALLADAS DE CONECTORES", "🔌")

print(" **GUÍAS PASO A PASO PARA CONECTORES PRINCIPALES**")
print()

# GOOGLE SHEETS - GUÍA COMPLETA
print(" **GOOGLE SHEETS - GUÍA COMPLETA**")
print("=" * 40)

google_sheets_guide = {
    "TRIGGERS DISPONIBLES": [
        ("New Spreadsheet Row", "Cuando se agrega nueva fila", "Ideal para formularios"),
        ("Updated Spreadsheet Row", "Cuando se modifica fila", "Para seguimiento de cambios"),
        ("New Spreadsheet", "Cuando se crea nueva hoja", "Para gestión de proyectos")
    ],
    "ACTIONS DISPONIBLES": [
        ("Create Spreadsheet Row", "Agregar nueva fila", "Más común"),
        ("Update Spreadsheet Row", "Modificar fila existente", "Requiere identificador"),
        ("Lookup Spreadsheet Row", "Buscar fila específica", "Para validaciones"),
        ("Create Spreadsheet", "Crear nueva hoja", "Para reportes automáticos")
    ],
    "TIPS DE CONFIGURACIÓN": [
        "Siempre usa la primera fila como headers",
        "Evita celdas vacías en los headers",
        "Usa formatos consistentes (fechas, números)",
        "Configura permisos de edición correctos",
        "Prueba con datos reales antes de activar"
    ],
    "ERRORES COMUNES": [
        "Headers con espacios o caracteres especiales",
        "Permisos insuficientes en la hoja",
        "Formato de fecha incorrecto",
        "Intentar actualizar fila sin identificador único"
    ]
}

for seccion, contenido in google_sheets_guide.items():
    print(f"\n **{seccion}**")
    if seccion in ["TRIGGERS DISPONIBLES", "ACTIONS DISPONIBLES"]:
        for nombre, descripcion, uso in contenido:
            print(f"   • **{nombre}**: {descripcion} - {uso}")
    else:
        for item in contenido:
            print(f"   • {item}")

# GMAIL - GUÍA COMPLETA
print("\n **GMAIL - GUÍA COMPLETA**")
print("=" * 40)

gmail_guide = {
    "TRIGGERS MÁS ÚTILES": [
        ("New Email", "Cualquier email nuevo", "Filtrar por remitente/asunto"),
        ("New Labeled Email", "Email con etiqueta específica", "Mejor para organización"),
        ("New Starred Email", "Email marcado como importante", "Para emails prioritarios"),
        ("New Attachment", "Email con adjunto", "Para procesar documentos")
    ],
    "ACTIONS MÁS ÚTILES": [
        ("Send Email", "Enviar email", "Respuestas automáticas"),
        ("Create Draft", "Crear borrador", "Para revisión manual"),
        ("Add Label", "Agregar etiqueta", "Organización automática"),
        ("Mark as Read", "Marcar como leído", "Gestión de bandeja")
    ],
    "CONFIGURACIÓN AVANZADA": [
        "Usa filtros de Gmail para pre-organizar",
        "Configura etiquetas específicas para Zapier",
        "Habilita IMAP si tienes problemas de conexión",
        "Usa plantillas de email para respuestas consistentes"
    ]
}

for seccion, contenido in gmail_guide.items():
    print(f"\n **{seccion}**")
    if seccion in ["TRIGGERS MÁS ÚTILES", "ACTIONS MÁS ÚTILES"]:
        for nombre, descripcion, uso in contenido:
            print(f"   • **{nombre}**: {descripcion} - {uso}")
    else:
        for item in contenido:
            print(f"   • {item}")

# SLACK - GUÍA COMPLETA
print("\n **SLACK - GUÍA COMPLETA**")
print("=" * 40)

slack_guide = {
    "CONFIGURACIÓN INICIAL": [
        "Instala la app de Zapier en tu workspace",
        "Configura permisos para canales específicos",
        "Crea canales dedicados para notificaciones automáticas",
        "Define formato estándar para mensajes automáticos"
    ],
    "MEJORES PRÁCTICAS": [
        "Usa emojis para identificar tipos de notificación",
        "Menciona usuarios específicos cuando sea necesario",
        "Agrupa notificaciones similares en threads",
        "Configura horarios de no molestar",
        "Usa canales específicos, no #general"
    ],
    "FORMATOS DE MENSAJE EFECTIVOS": [
        "🚨 URGENTE: {asunto} - {remitente}",
        "📊 Nuevo lead: {nombre} - {empresa} - {email}",
        "✅ Tarea completada: {proyecto} - {responsable}",
        "💰 Nueva venta: ${monto} - {cliente} - {producto}"
    ]
}

for seccion, contenido in slack_guide.items():
    print(f"\n **{seccion}**")
    for item in contenido:
        print(f"   • {item}")

print("\n" + "="*80)
print(" **RESUMEN: INTRODUCCIÓN A ZAPIER**")
print("="*80)
print()
print(" **Lo que hemos cubierto:**")
print("    Conceptos básicos de Zapier y terminología")
print("    Top 20 aplicaciones más conectadas")
print("    Tutorial paso a paso para crear tu primer Zap")
print("    Ejemplos prácticos por industria")
print("    Guías detalladas de conectores principales")
print()
print(" **Próximos pasos para estudiantes:**")
print()
print(" **Para principiantes:**")
print("   1. Crea cuenta gratuita en Zapier")
print("   2. Conecta Gmail y Google Sheets")
print("   3. Crea un Zap simple de 2 pasos")
print("   4. Prueba con datos reales")
print()
print(" **Para intermedios:**")
print("   1. Agrega filtros y formatters")
print("   2. Crea Zaps multi-paso (3-5 acciones)")
print("   3. Experimenta con diferentes triggers")
print("   4. Configura notificaciones de error")
print()
print(" **Para avanzados:**")
print("   1. Usa Paths para lógica condicional")
print("   2. Implementa webhooks personalizados")
print("   3. Crea flujos de trabajo complejos")
print("   4. Monitorea métricas de automatización")
print()
print(" **Recursos adicionales:**")
print("   • Zapier University (cursos gratuitos)")
print("   • Zapier Community (foro de usuarios)")
print("   • Templates de Zapier por industria")
print("   • Documentación oficial de cada app")
# Out:
# ...
# ⚡                      ZAPIER: AUTOMATIZACIÓN SIN CÓDIGO                       ⚡
# ...
#
#  **¿Qué es Zapier?**
#    Zapier es una plataforma que conecta más de 5,000 aplicaciones
#    para automatizar tareas repetitivas SIN necesidad de programar.
#
#  **Conceptos básicos que DEBES conocer:**
#     **ZAP**: Una automatización completa (ej: Gmail → Google Sheets)
#     **TRIGGER**: El evento que inicia la automatización (ej: nuevo email)
#     **ACTION**: Lo que sucede después del trigger (ej: crear fila en Sheets)
#     **FILTER**: Condición para que se ejecute (ej: solo emails importantes)
#     **FORMATTER**: Herramienta para modificar datos (ej: cambiar formato de fecha)
#     **DELAY**: Pausa entre acciones (ej: esperar 5 minutos)
#     **PATH**: Diferentes rutas según condiciones (ej: si/entonces)
#
#  **Planes de Zapier (2024):**
#     **FREE**: 100 tareas/mes - Zaps de 2 pasos - Ideal para probar
#     **STARTER**: $19.99/mes - 750 tareas/mes - Zaps multi-paso, filtros
# ...
